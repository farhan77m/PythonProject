# %%
#Importing libraries in notebook
import pandas as pd
import numpy as np

# %%
#Importing libraries in notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing given csv file for the Project02
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
#The first 10 rows
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
#The last 10 rows
df.tail(10)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101756     443842070    140199494            Other  Female  [60-70)      ?
# 101757     443842136    181593374        Caucasian  Female  [70-80)      ?
# 101758     443842340    120975314        Caucasian  Female  [80-90)      ?
# 101759     443842778     86472243        Caucasian    Male  [80-90)      ?
# 101760     443847176     50375628  AfricanAmerican  Female  [60-70)      ?
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
#The summary description of the data
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
#The shape of the data
df.shape
# Out:
# (101766, 50)

# %%
#The information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
#The sum of isna of the data frame
df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         encounter_id  patient_nbr   race  gender    age  weight  \
# 0              False        False  False   False  False   False
# 1              False        False  False   False  False   False
# 2              False        False  False   False  False   False
# 3              False        False  False   False  False   False
# 4              False        False  False   False  False   False
# ...              ...          ...    ...     ...    ...     ...
# 101761         False        False  False   False  False   False
# 101762         False        False  False   False  False   False
# 101763         False        False  False   False  False   False
# 101764         False        False  False   False  False   False
# 101765         False        False  False   False  False   False
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
#Values of gender in the data frame
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Unknown/Invalid'], dtype=object)

# %%
#Values of time_in_hospital in the data frame
df['time_in_hospital'].unique()
# Out:
# array([ 1,  3,  2,  4,  5, 13, 12,  9,  7, 10,  6, 11,  8, 14],
#       dtype=int64)

# %%
#Values of admission_type_id in the data frame
df['admission_type_id'].unique()
# Out:
# array([6, 1, 2, 3, 4, 5, 8, 7], dtype=int64)

# %%
#Values of num_lab_procedures in the data frame
df['num_lab_procedures'].unique()
# Out:
# array([ 41,  59,  11,  44,  51,  31,  70,  73,  68,  33,  47,  62,  60,
#         55,  49,  75,  45,  29,  35,  42,  66,  36,  19,  64,  25,  53,
#         52,  87,  27,  37,  46,  28,  48,  72,  10,   2,  65,  67,  40,
#         54,  58,  57,  43,  32,  83,  34,  39,  69,  38,  56,  22,  96,
#         78,  61,  88,  50,   1,  18,  82,   9,  63,  24,  71,  77,  81,
#         76,  90,  93,   3, 103,  13,  80,  85,  16,  15,  12,  30,  23,
#         17,  21,  79,  26,   5,  95,  97,  84,  14,  74, 105,  86,  98,
#         20,   6,  94,   8, 102, 100,   7,  89,  91,  92,   4, 101,  99,
#        114, 113, 111, 129, 107, 108, 106, 104, 109, 120, 132, 121, 126,
#        118], dtype=int64)

# %%
#Grouping for number of records of gender
df.groupby(['gender'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: encounter_id, dtype: int64

# %%
#Grouping for number of records of time_in_hospital
df.groupby(['time_in_hospital'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# time_in_hospital
# 3     17756
# 2     17224
# 1     14208
# 4     13924
# 5      9966
# 6      7539
# 7      5859
# 8      4391
# 9      3002
# 10     2342
# 11     1855
# 12     1448
# 13     1210
# 14     1042
# Name: encounter_id, dtype: int64

# %%
#Grouping for number of records for admission_type_id
df.groupby(['admission_type_id'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# admission_type_id
# 1    53990
# 3    18869
# 2    18480
# 6     5291
# 5     4785
# 8      320
# 7       21
# 4       10
# Name: encounter_id, dtype: int64

# %%
#Grouping for records of num_lab_procedures
df.groupby(['num_lab_procedures'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# num_lab_procedures
# 1      3208
# 43     2804
# 44     2496
# 45     2376
# 38     2213
#        ...
# 120       1
# 121       1
# 126       1
# 129       1
# 132       1
# Name: encounter_id, Length: 118, dtype: int64

# %%
# Check for missing values in num_lab_procedures
missing_values = df['num_lab_procedures'].isnull().sum()
print(f"\nNumber of missing values in num_lab_procedures: {missing_values}")

# Replace missing values with the mean
df['num_lab_procedures'].fillna(df['num_lab_procedures'].mean(), inplace=True)
# Out:
# Number of missing values in num_lab_procedures: 0

# %%
# Check for missing values in time_in_hospital
missing_values = df['time_in_hospital'].isnull().sum()
print(f"Number of missing values in time_in_hospital: {missing_values}")

# Replace missing values with the median
df['time_in_hospital'].fillna(df['time_in_hospital'].median(), inplace=True)
# Out:
# Number of missing values in time_in_hospital: 0

# %%
# Vizualization for time_in_hospital by gender
plt.figure(figsize=(12, 8))
sns.boxplot(x='gender', y='time_in_hospital', data=df)
plt.title('Distribution of Time in Hospital by Gender')
plt.xlabel('Gender')
plt.ylabel('Time in Hospital')
plt.show()

# %%
# Visualization for Number of Lab Procedure by Admmission Type Id
plt.figure(figsize=(12, 8))
sns.boxplot(x='admission_type_id', y='num_lab_procedures', data=df)
plt.title('Distribution of Number of Lab Procedures by Admission Type Id')
plt.xlabel('Admission Type Id')
plt.ylabel('Number of Lab Procedures')
plt.show()

# %%
# The first vizualization we can see that female and male spent almost the same time in the hospital
